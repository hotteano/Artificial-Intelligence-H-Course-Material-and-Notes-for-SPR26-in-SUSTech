# %%
import numpy as np
import util
from NNS import NNS

# %% [markdown]
# ## 1. Data Loading

# %%
retrieval_repository_data = util.load_data('./image_retrieval_repository_data.pkl')

# %% [markdown]
# ## 2. Data Exploration

# %%
print("Image Retrieval Repository Data Shape:", retrieval_repository_data.shape)
# Out:
# Image Retrieval Repository Data Shape: (5000, 257)

# %% [markdown]
# ## 3. Data Preprocessing

# %%
# remove index column
repository_data_index = retrieval_repository_data[:, 0]
retrieval_repository_data = retrieval_repository_data[:, 1:]

# %%
repository_data_index.shape
# Out:
# (5000,)

# %%
retrieval_repository_data.shape
# Out:
# (5000, 256)

# %% [markdown]
# ## 4. Model

# %%
nns_model = NNS(k=5)
import retrieval
retrieval = retrieval.Retrieval()

# %% [markdown]
# ## 5. Train

# %%
nns_model.fit(X_train=retrieval_repository_data)
retrieval.fit(X_train=retrieval_repository_data)

# %% [markdown]
# ## 6. Predict

# %%
k_nearest = nns_model.predict(retrieval_repository_data[:1000])
k_nearest_retrieval = retrieval.predict(retrieval_repository_data[:1000])
# Out:
#  36%|███▋      | 365/1000 [00:08<00:14, 45.18it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 k_nearest = nns_model.predict(retrieval_repository_data[:1000])
#       2 k_nearest_retrieval = retrieval.predict(retrieval_repository_data[:1000])
#
# File c:\Users\edwar\Notes\Artificial-Intelligence-Course-Material-and-Notes-for-SPR26-in-SUSTech\Project2\codebase\task2\NNS.py:36, in NNS.predict(self, X_test)
#      34 y_pred = []
#      35 for x in tqdm(X_test):
# ---> 36     k_indices = self._predict(x)
#      37     y_pred.append(k_indices)
#      38 return np.array(y_pred)
#
# File c:\Users\edwar\Notes\Artificial-Intelligence-Course-Material-and-Notes-for-SPR26-in-SUSTech\Project2\codebase\task2\NNS.py:50, in NNS._predict(self, x)
#      40 def _predict(self, x):
#      41     """
#      42     Find the IDs of the k repository data points that are closest to the single test data point.
#      43
#    (...)
#      48     - k_indices: IDs of the k repository data points that are closest to the test sample point.
#      49     """
# ---> 50     distances = [np.sum((x - x_train)**2) for x_train in self.X_train]
#      51     k_indices = np.argsort(distances)[:self.k]
#      52     return k_indices
#
# File c:\Users\edwar\Notes\Artificial-Intelligence-Course-Material-and-Notes-for-SPR26-in-SUSTech\Project2\codebase\task2\NNS.py:50, in <listcomp>(.0)
#      40 def _predict(self, x):
#      41     """
#      42     Find the IDs of the k repository data points that are closest to the single test data point.
#      43
#    (...)
#      48     - k_indices: IDs of the k repository data points that are closest to the test sample point.
#      49     """
# ---> 50     distances = [np.sum((x - x_train)**2) for x_train in self.X_train]
#      51     k_indices = np.argsort(distances)[:self.k]
#      52     return k_indices
#
# File c:\Users\edwar\miniconda3\envs\py310_iem\lib\site-packages\numpy\core\fromnumeric.py:2313, in sum(a, axis, dtype, out, keepdims, initial, where)
#    2310         return out
#    2311     return res
# -> 2313 return _wrapreduction(a, np.add, 'sum', axis, dtype, out, keepdims=keepdims,
#    2314                       initial=initial, where=where)
#
# File c:\Users\edwar\miniconda3\envs\py310_iem\lib\site-packages\numpy\core\fromnumeric.py:72, in _wrapreduction(obj, ufunc, method, axis, dtype, out, **kwargs)
#      71 def _wrapreduction(obj, ufunc, method, axis, dtype, out, **kwargs):
# ---> 72     passkwargs = {k: v for k, v in kwargs.items()
#      73                   if v is not np._NoValue}
#      75     if type(obj) is not mu.ndarray:
#      76         try:
#
# KeyboardInterrupt:

# %%
print(k_nearest.shape)
print(k_nearest_retrieval.shape)
# Out:
# (1000, 5)
# (1000, 5)
